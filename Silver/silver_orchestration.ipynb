# %%
notebooks=[
"/Workspace/Repos/kdeepika11@gmail.com/DataLakeHouseProject/Silver/crm/silver_crm_cust_info",
"/Workspace/Repos/kdeepika11@gmail.com/DataLakeHouseProject/Silver/crm/silver_crm_product_info",
"/Workspace/Repos/kdeepika11@gmail.com/DataLakeHouseProject/Silver/crm/silver_crm_sales_details",
"/Workspace/Repos/kdeepika11@gmail.com/DataLakeHouseProject/Silver/erp/silver_erp_accessory_category",
"/Workspace/Repos/kdeepika11@gmail.com/DataLakeHouseProject/Silver/erp/silver_erp_customerinfo",
"/Workspace/Repos/kdeepika11@gmail.com/DataLakeHouseProject/Silver/erp/silver_erp_location"
]

for i in notebooks:
  dbutils.notebook.run(i, timeout_seconds=0)
