# %%
notebooks=[
"/Workspace/Repos/kdeepika11@gmail.com/DataLakeHouseProject/Gold/gold_dim_customers",
"/Workspace/Repos/kdeepika11@gmail.com/DataLakeHouseProject/Gold/gold_dim_products",
"/Workspace/Repos/kdeepika11@gmail.com/DataLakeHouseProject/Gold/gold_fact_sales"
]

for i in notebooks:
  dbutils.notebook.run(i, timeout_seconds=0)
